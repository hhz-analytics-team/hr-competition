# %% [markdown]
# <img src='logo/dsl-logo.png' width="500" align="center" />

# %% [markdown]
# # HR Competition

# %% [markdown]
# ## Univariate Analysis
# Bei der univariaten Analyse können nur allgemeine Schlüsse zu dem Unternehmen gezogen werden, da nur eine Dimension betrachtet wird.

# %% [markdown]
# ### Initializations
#
# Es werden die benötigten Bibliotheken eingebunden und für Variationsmöglichkeiten bei der Ausgabe wird class color definiert.

# %%
# Bibliotheken einbinden
import math
import numpy as np
import scipy.stats as stats
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Definition einer Klasse für Text Styles
class color:
   PURPLE = '\033[95m'
   CYAN = '\033[96m'
   DARKCYAN = '\033[36m'
   BLUE = '\033[94m'
   GREEN = '\033[92m'
   YELLOW = '\033[93m'
   RED = '\033[91m'
   BOLD = '\033[1m'
   UNDERLINE = '\033[4m'
   END = '\033[0m'

# %%
df = pd.read_pickle('exchange/hr_01_cleaned_train.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 10 columns):
# satisfactionLevel       10000 non-null float64
# yearsSinceEvaluation    10000 non-null float64
# numberOfProjects        10000 non-null int64
# averageMonthlyHours     10000 non-null int64
# yearsAtCompany          10000 non-null int64
# workAccident            10000 non-null category
# hasLeftCompany          10000 non-null category
# gotPromotion            10000 non-null category
# department              10000 non-null category
# salary                  10000 non-null category
# dtypes: category(5), float64(2), int64(3)
# memory usage: 439.7 KB

# %% [markdown]
# ### Histograms of Number Attributes
# Die Verwendung der Histogramme ermöglicht eine schnelle Prüfung der Daten auf Normalverteilung nach Gauß.

# %%
# Visualisierung der Häufigkeitsverteilung der Attribute mit Zahlenwerten
count_number_colums = df.select_dtypes(include=[np.number]).columns.size
f, a = plt.subplots(math.floor(count_number_colums/2) + count_number_colums%2, 2, figsize=(16,16))
a = a.ravel()
for idx, col in enumerate(df.select_dtypes(include=[np.number])):
    a[idx].hist(df[col])
    a[idx].set_xlabel(col, weight='bold')
if count_number_colums%2 == 1 :
    a[-1].axis('off')

# %% [markdown]
# #### Fazit Histogramme
# - Bei der Spalte **averageMonthlyHours** kann eine Normalverteilung angenommen werden.
# - Zusätzlich wird die Annahme getroffen, dass es sich bei den Mitarbeitern mit geringerer Stundenanzahl um Teilzeitkräfte handelt.
#
#
# - An dem Verlauf der Graphen numberOfProjects und yearsAtCompany kann die dargelegte Korrelation visuell belegt werden.

# %% [markdown]
# ### Countplots of Category Attributes

# %%
# Visualisierung der Häufigkeitsverteilung der Attribute mit Categories
count_number_colums = df.select_dtypes(include=['category']).columns.size
f, a = plt.subplots(math.floor(count_number_colums/2) + count_number_colums%2, 2, figsize=(16,16))
a = a.ravel()
for idx, col in enumerate(df.select_dtypes(include=['category']).drop(['department'], axis=1)):
    sns.countplot(x=col, data=df, ax=a[idx])
    a[idx].set_xlabel(col, weight='bold')
a = plt.subplot2grid((3, 2), (2, 0), colspan=2)
a.set_xlabel(col, weight='bold')
sns.countplot(x='department', data=df, ax=a);

# %% [markdown]
# ### Comparison of High Potentials and Normal Employees

# %%
df = pd.read_pickle('exchange/hr_01_enriched_train.pkl')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 17 columns):
# satisfactionLevel                  10000 non-null float64
# yearsSinceEvaluation               10000 non-null float64
# numberOfProjects                   10000 non-null int64
# averageMonthlyHours                10000 non-null int64
# yearsAtCompany                     10000 non-null int64
# workAccident                       10000 non-null category
# hasLeftCompany                     10000 non-null category
# gotPromotion                       10000 non-null category
# department                         10000 non-null category
# salary                             10000 non-null category
# projectsPerYear                    10000 non-null float64
# hoursPerProject                    10000 non-null float64
# satisfactionHours                  10000 non-null float64
# workingHoursSinceLastEvaluation    10000 non-null float64
# evaluationSatisfaction             10000 non-null float64
# projectsPerWorkingHour             10000 non-null float64
# valuableEmployee                   10000 non-null int64
# dtypes: category(5), float64(8), int64(4)
# memory usage: 986.6 KB

# %%
df_high = df[df['valuableEmployee']==1]
df_high.describe()
# Out:
#        satisfactionLevel  yearsSinceEvaluation  numberOfProjects  \
# count        1124.000000           1124.000000       1124.000000
# mean            0.750890              0.726717          4.510676
# std             0.142076              0.159394          0.662487
# min             0.510000              0.370000          2.000000
# 25%             0.630000              0.590000          4.000000
# 50%             0.740000              0.730000          5.000000
# 75%             0.870000              0.870000          5.000000
# max             1.000000              1.000000          7.000000
#
#        averageMonthlyHours  yearsAtCompany  projectsPerYear  hoursPerProject  \
# count          1124.000000     1124.000000      1124.000000      1124.000000
# mean            179.223310        2.461744         1.949173      1211.834926
# std              30.212647        0.864536         0.423735       691.552829
# min              98.000000        2.000000         0.285714       428.000000
# 25%             156.000000        2.000000         1.666667       934.800000
# 50%             179.000000        2.000000         2.000000      1092.000000
# 75%             205.000000        3.000000         2.000000      1308.000000
# max             229.000000       10.000000         3.500000      7400.000000
#
#        satisfactionHours  workingHoursSinceLastEvaluation  \
# count        1124.000000                      1124.000000
# mean          134.849822                      1564.881246
# std            35.431606                       441.412864
# min            49.980000                       493.920000
# 25%           106.820000                      1224.000000
# 50%           131.520000                      1522.260000
# 75%           160.020000                      1881.600000
# max           229.000000                      2684.880000
#
#        evaluationSatisfaction  projectsPerWorkingHour  valuableEmployee
# count             1124.000000             1124.000000            1124.0
# mean                 0.545782                0.003147               1.0
# std                  0.159094                0.001158               0.0
# min                  0.197600                0.001123               1.0
# 25%                  0.431600                0.002334               1.0
# 50%                  0.528000                0.002949               1.0
# 75%                  0.646000                0.003707               1.0
# max                  0.970200                0.011338               1.0

# %%
df_normal = df[df['valuableEmployee']==0]
df_normal.describe()
# Out:
#        satisfactionLevel  yearsSinceEvaluation  numberOfProjects  \
# count        8876.000000           8876.000000       8876.000000
# mean            0.593515              0.715864          3.710793
# std             0.253875              0.172883          1.261013
# min             0.090000              0.360000          2.000000
# 25%             0.410000              0.560000          3.000000
# 50%             0.620000              0.720000          4.000000
# 75%             0.810000              0.870000          4.000000
# max             1.000000              1.000000          7.000000
#
#        averageMonthlyHours  yearsAtCompany  projectsPerYear  hoursPerProject  \
# count          8876.000000     8876.000000      8876.000000      8876.000000
# mean            203.406377        3.612551         1.123716      2497.183966
# std              51.402392        1.456469         0.449442      1212.386012
# min              96.000000        2.000000         0.200000       436.000000
# 25%             156.000000        3.000000         0.750000      1737.450000
# 50%             205.000000        3.000000         1.000000      2304.000000
# 75%             249.000000        4.000000         1.500000      2856.000000
# max             310.000000       10.000000         3.000000     13500.000000
#
#        satisfactionHours  workingHoursSinceLastEvaluation  \
# count        8876.000000                      8876.000000
# mean          120.987598                      1786.417084
# std            63.939389                       713.683377
# min            13.200000                       448.440000
# 25%            61.200000                      1175.220000
# 50%           120.070000                      1708.800000
# 75%           172.380000                      2377.800000
# max           282.440000                      3608.400000
#
#        evaluationSatisfaction  projectsPerWorkingHour  valuableEmployee
# count             8876.000000             8876.000000            8876.0
# mean                 0.429871                0.002312               0.0
# std                  0.228916                0.001048               0.0
# min                  0.046800                0.000608               0.0
# 25%                  0.220000                0.001683               0.0
# 50%                  0.428800                0.002118               0.0
# 75%                  0.608000                0.002624               0.0
# max                  0.990000                0.012531               0.0

# %% [markdown]
# ### Histograms of Number Attributes

# %%
# Visualisierung der Häufigkeitsverteilung der Attribute mit Zahlenwerten
count_number_colums = df.select_dtypes(include=[np.number]).drop('valuableEmployee', axis=1).columns.size
f, a = plt.subplots(count_number_colums, 2, figsize=(16,64))
a = a.ravel()
for idx, col in enumerate(df.drop('valuableEmployee', axis=1).select_dtypes(include=[np.number])):
    a[idx*2].hist(df_high[col])
    a[idx*2].set_xlabel(col + ' for high potential', weight='bold')
    a[idx*2+1].hist(df_normal[col])
    a[idx*2+1].set_xlabel(col + ' for normal potential', weight='bold')

# %% [markdown]
# ### Countplots of Category Attributes

# %%
# Visualisierung der Häufigkeitsverteilung der Attribute mit Categories
count_number_colums = df.select_dtypes(include=['category']).columns.size
f, a = plt.subplots(count_number_colums, 2, figsize=(16,32))
a = a.ravel()
for idx, col in enumerate(df.select_dtypes(include=['category']).drop(['department'], axis=1)):
    sns.countplot(x=col, data=df_high, ax=a[idx*2])
    a[idx*2].set_xlabel(col + ' for high potential', weight='bold')
    sns.countplot(x=col, data=df_normal, ax=a[idx*2+1])
    a[idx*2+1].set_xlabel(col + ' for normal potential', weight='bold')
a = plt.subplot2grid((5, 2), (3, 0), colspan=2)
sns.countplot(x='department', data=df_high, ax=a)
a.set_xlabel('department for high potential', weight='bold')
a = plt.subplot2grid((5, 2), (4, 0), colspan=2)
sns.countplot(x='department', data=df_normal, ax=a)
a.set_xlabel('department for normal potential', weight='bold');
